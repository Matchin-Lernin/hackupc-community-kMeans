# %%
import pandas as pd
import numpy as np

songsDb = pd.read_csv('datasets/final/songDb.tsv')

newSongsDB = songsDb.filter(['Danceability', 'Energy', 'Key', 'Loudness', 'Mode', 'Speechness', 'Acousticness', 'Instrumentalness', 'Liveness', 'Valence', 'Tempo'])
metadataDB = songsDb.filter(['Name', 'Type', 'ID', 'Uri', 'Ref_track', 'URL_features', 'Duration_ms', 'time_signature', 'Genre'])

newSongsDB.to_csv('datasets/final/newSongDb.csv')
metadataDB.to_csv('datasets/final/metadataDB.csv')
# Out:
# /Users/JordiROP/Library/Python/3.7/lib/python/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (11,18) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
